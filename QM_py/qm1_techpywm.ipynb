# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/kulinskij-tech/QuantumMechanics1/blob/main/QM_py/qm1_techpywm.ipynb)

# %% [markdown]
# # Програмне забезпечення: <br> Pytnon+Jupyter notebook +WolframEngine
#
# $\newcommand{\ket}[1]{\left.\left\vert\, #1\,\right. \right \rangle}$
# $\newcommand{\bra}[1]{\left. \langle \, #1\, \right\vert}$
# $\newcommand{\braket}[2]{\langle \,#1 \vert #2 \, \rangle}$
# $\newcommand{\av}[3]{\left\langle \,#1 \left \vert\, #2 \,\right\vert #3 \,\right \rangle}$
#
# __викладач: проф. Кулінський В.Л.__
#
# Посібник оформлений як колекція <a href="https://en.wikipedia.org/wiki/Project_Jupyter"> Jupyter</a>  notebooks з використанням <a href="https://www.python.org/">Python</a> пакетів <a href="https://scipy.org"> Matplotlib, NumPy, SciPy, SymPy</a>. Таким чином студенти матимуть змогу виконувати самостійні завдання на своїх PC чи у комп'ютерному класі, водночас вдосконалюючи навички Python-програмування та навчаючись представленню результатів загально відомими у науковому середовищі засобами $\LaTeX$+<a href="https://ipython.org"> IPython</a>. Крім того у  2019 році Wolfram Research виклала у вільний доступ
# <a href="https://www.wolfram.com/developer/"> Free Wolfram Engine for Developers</a>.
# Це інтерпретатор (обчислювальне ядро) системи <a href="https://www.wolfram.com/mathematica/"> Mathematica</a>. Тепер усі бажаючи можуть  безкоштовно(!) встановити його і працювати, використовуючи <a href="https://en.wikipedia.org/wiki/Project_Jupyter"> Jupyter notebook</a> в якості <a href="https://github.com/WolframResearch/WolframLanguageForJupyter">FrontEnd</a>.
# На відміну від вказаних вище Python-based систем користання якими для початківців може буто пов'язано з великими витратами часу на вивчення різноманітних бібліотек і їх кокретних особливостей, ця система з самого початку базується на єдиному синтаксичному принципі, та використовує силу функціональної парадигми програмування. Це дає більшу економію часу та знижує вхідний поріг для ефективного програмування складних задач. Вона також має велику бібліотеку спеціальних функцій які зустічаються при розв'язанні задач з квантової механіки і стане у нагоді при проведенні символічних, чисельних розрахунків та візуалізації результатів.
# ***
# - <a href='https://mathematica.stackexchange.com/questions/198839/how-to-add-a-front-end-to-the-free-wolfram-engine'> Як встановити WE+JN (1)</a>
# - <a href='https://www.davecwright.org/post/mathematica_jupyter/'> Як встановити WE+JN (2)</a>
# - <a href='https://compbiomech.github.io/info/wolframengine.html'> Як встановити WE+JN (3)</a>
# ***
# Приклад використання WM+JN(under Anaconda) показаний нижче.

# %%
from IPython.display import HTML

HTML("""
<div align="middle">
<video width="80%" controls>
      <source src="./figs/WME_Jupyter_Anaconda.mp4" type="video/mp4">
</video></div>""")
# Out:
# <div align="middle">
# <video width="80%" controls>
#       <source src="./figs/WME_Jupyter_Anaconda.mp4" type="video/mp4">
# </video></div>

# %% [markdown]
# <img src="./figs/wm_kernel_jupyter.png" alt="Image" style="width:80%">
# <center>Додавання WE-kernel до jupyter kernel list (Windows) </center>
# <br>
# <img src="./figs/wm_kernel_jupyter_linux.png" alt="Image" style="width:80%">
# <center>Додавання WE-kernel до jupyter kernel list (Linux) </center>

# %% [markdown]
# Тим хто використовує Jupyter notebook можна порадити встановити <a href='https://github.com/ipython-contrib/jupyter_contrib_nbextensions'>Jupyter extensions</a> для <a href='https://towardsdatascience.com/jupyter-notebook-extensions-517fa69d2231'>зручності конфігурування</a>
