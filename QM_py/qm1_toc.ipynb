# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/kulinskij-tech/QuantumMechanics1/blob/main/QM_py/qm1_toc.ipynb)

# %% [markdown]
# # Квантова Механіка: <br> Лекції та задачі для практичних занять (частина 1) <br> (Jupyter notebook handouts)
#
# $\newcommand{\ket}[1]{\left.\left\vert\, #1\,\right. \right \rangle}$
# $\newcommand{\bra}[1]{\left. \langle \, #1\, \right\vert}$
# $\newcommand{\braket}[2]{\langle \,#1 \vert #2 \, \rangle}$
# $\newcommand{\av}[3]{\left\langle \,#1 \left \vert\, #2 \,\right\vert #3 \,\right \rangle}$
#
# <!-- <a href="https://www.patreon.com/bePatron?u=45210572" data-patreon-widget-type="become-patron-button">Become a Patron!</a><script async src="https://c6.patreon.com/becomePatronButton.bundle.js"></script>
#  -->
# Публікується за рішенням Вченої ради
# факультета математики, фізики та інформаційних технологій
# Одеського національного університета: Протокол <ins>№ ?</ins>
# від <ins>?.?.2026</ins>
#
# __викладач: проф. Кулінський В.Л.__
#
# Посібник містить теоретичний матеріал та задачі, що пропонуються студентам 3 курсу на практичних заняттях за першою частиною курса "Квантовая механіка". Задачі мають точні аналітичні розв'язки і надаються для демонстрації та засвоєння основних положеннь і понять квантової механіки. На початку кожного розділу наведено необхідного теоретичного матеріалу (згідно з матеріалом лекцій) для їх розв'язку. Поряд із традиційними задачами на розв'язок рівняння Шредінгера розглядаються також алгебраічні операторні методи та елементи квантової інформатики.
#
# [Технічне метод забезпечення курсу](./qm_technotes.ipynb)

# %% [markdown]
# __Мета:__ вивчення основних положень квантової теорії та методів розв'язків задач; формування навичок аналізу квантових явищ, знайомство студентів з теоретичними основами сучасних нанотехнологій.
#
# __Завдання:__ засвоєння основних положень квантової теорії та вдосконалення навичок розв'язків задач. В результаті вивчення навчальної дисципліни студент повинен:
# - Знати: основні положення квантової теорії та її методи.
# - Вміти:
#   - аналізувати квантові явища використовуючи базові положення і основні методи
#   - розв'язувати типові задачі
#   - представляти результати самостійної роботи із використанням сучасних засобів презентації наукових результатів.
# ***
#
# ## Розділи
# - [Квантова природа світла та розповсюдження частинок](https://colab.research.google.com/github/kulinskij-tech/QuantumMechanics1/blob/main/QM_py/qm1_wavepack_theor.ipynb)
# - [Вільні хвильові пакети та їх еволюція. Обчислення середніх значень функцій від координат та імпульсів.](https://colab.research.google.com/github/kulinskij-tech/QuantumMechanics1/blob/main/QM_py/qm1_psi2.ipynb)<br>
#     - [Фур'є-розклад хвильових пакетів. Співвідношення невизначеностей Хайзенберга.](https://colab.research.google.com/github/kulinskij-tech/QuantumMechanics1/blob/main/QM_py/qm1_wavepack_zad.ipynb)<br>
#     - [Еволюція вільних хвильових пакетів.](https://colab.research.google.com/github/kulinskij-tech/QuantumMechanics1/blob/main/QM_py/qm1_wavepack_zadevolut.ipynb)<br>
# - [Структура простору станів квантових систем. Проекційні оператори.](https://colab.research.google.com/github/kulinskij-tech/QuantumMechanics1/blob/main/QM_py/qm1_spaceortheor.ipynb)<br>
#     - [Простір станів Q-bit](https://colab.research.google.com/github/kulinskij-tech/QuantumMechanics1/blob/main/QM_py/qm1_qbitspace.ipynb)
# - [Зображення спостережних величин ермітовими операторами. Спектр оператора.](https://colab.research.google.com/github/kulinskij-tech/QuantumMechanics1/blob/main/QM_py/qm1_ermitop_theor.ipynb)
#     - [Математичне доповненння: розширення ермітових операторів](https://colab.research.google.com/github/kulinskij-tech/QuantumMechanics1/blob/main/QM_py/qm1_ermitop_math.ipynb)
#     - [Задачі](https://colab.research.google.com/github/kulinskij-tech/QuantumMechanics1/blob/main/QM_py/qm1_ermitop_zad.ipynb)
# - [Рівняння Шредінгера для простих систем. Рівняння руху Хайзенберга для операторів.](https://colab.research.google.com/github/kulinskij-tech/QuantumMechanics1/blob/main/QM_py/qm1_scheiz_theor.ipynb)
#     - [Задачі](https://colab.research.google.com/github/kulinskij-tech/QuantumMechanics1/blob/main/QM_py/qm1_scheiz_zad.ipynb)
# - [Стаціонарні стани частинки у потенціальному полі. Одновимірне розсіяння.](https://colab.research.google.com/github/kulinskij-tech/QuantumMechanics1/blob/main/QM_py/qm1_stac_theor.ipynb)
#     - [Задачі](https://colab.research.google.com/github/kulinskij-tech/QuantumMechanics1/blob/main/QM_py/qm1_stac_zad.ipynb)
# - [Гармонічний осцилятор. Алгебра операторів нарождення-знищення.](https://colab.research.google.com/github/kulinskij-tech/QuantumMechanics1/blob/main/QM_py/qm1_osc.ipynb)
#     - [Задачі](https://colab.research.google.com/github/kulinskij-tech/QuantumMechanics1/blob/main/QM_py/qm1_osc_zad.ipynb)
# - [Інтеграли руху і симетрія. Момент імпульсу.](https://colab.research.google.com/github/kulinskij-tech/QuantumMechanics1/blob/main/QM_py/qm1_intsymom_theor.ipynb)
# <!--     - [Додатковий матеріал: Алгебра Лі групи $SU(3)$](./qm1_u3alg.ipynb) -->
#     - [Задачі](https://colab.research.google.com/github/kulinskij-tech/QuantumMechanics1/blob/main/QM_py/qm1_intsymom_zad.ipynb)
# - [Спін. Гамільтоніан Паулі.](https://colab.research.google.com/github/kulinskij-tech/QuantumMechanics1/blob/main/QM_py/qm1_spinpauli_theor.ipynb)
#     - [Задачі](https://colab.research.google.com/github/kulinskij-tech/QuantumMechanics1/blob/main/QM_py/qm1_spinpauli_zad.ipynb)
# - [Задача Кеплера в квантовій механіці. Спект атома водню.](https://colab.research.google.com/github/kulinskij-tech/QuantumMechanics1/blob/main/QM_py/qm1_atomh_theor.ipynb)
#     - [Задачі](https://colab.research.google.com/github/kulinskij-tech/QuantumMechanics1/blob/main/QM_py/qm1_atomh_zad.ipynb)
# - [Основи квантових обчислень](https://colab.research.google.com/github/kulinskij-tech/QuantumMechanics1/blob/main/QM_py/qm1_QinfoTheory.ipynb)
# <!--   - [Квантові кореляції](https://colab.research.google.com/github/kulinskij-tech/QuantumMechanics1/blob/main/QM_py/qm1_qcorr.ipynb) -->
#
#
# ### __Рекомендована література__
# 1. Landau L.D., Lifshitz Е.М. Quantum Mechanics: Non-relativistic theory, Pergamon Press 2013.
# 1.  Dirac P.А., Principles of Quantum Mechanics, OUP
# 1. Юхновський І.Р., Квантова механіка, К. Либідь 1995.
# 1. Глауберман А.Ю. Квантова механіка, Одеса, Астропринт, 2017
# 1. Вакарчук I.О., Квантова механiка, Вид-во ЛДУ, Львiв, 1998.
# 1. Висоцький В.I., Квантова механiка, Вид-во КНУ, Київ, 2008.
# 1. Flugge Z. Practical Quantum Mechanics, Springer Berlin, 1999
# 1. Bohm A. Quantum Mechanics: Foundations and Applications, Springer, 1993
# 1. Cohen-Tannoudji C., Diu B., Laloe F. Quantum Mechanics, Wiley-VCH, 1973
# ***
#
# # Quantum Mechanics: <br> Lectures and Problem solving (part 1)
#
#
# __Lecturer: Prof. Kulinskii V.L.__
